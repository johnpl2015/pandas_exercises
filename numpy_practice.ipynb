# %% [markdown]
# <a href="https://colab.research.google.com/github/johnpl2015/pandas_exercises/blob/master/numpy_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NUMPY EXCERCISES

# %% [markdown]
# [link text](https://www.youtube.com/watch?v=_duqyDP-Wmk&list=PL_dsdStdDXbq7XcLeuM8tp9_WTPKNpmjn&index=2)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
# ---

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr[0]
# Out:
# 1

# %%
arr[-1]
# Out:
# 6

# %%
arr[-1:2]
# Out:
# array([], dtype=int64)

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr[1:-1]
# Out:
# array([2, 3, 4, 5])
